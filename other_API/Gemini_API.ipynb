# %%
# Google generative AI:
from google import genai
from google.genai import types

# Packages to process the generated image:
from PIL import Image
from io import BytesIO

from IPython.display import display

# Packages to load the .env file:
import os
# from dotenv import load_dotenv

# %%
# Google generative AI:
from google import genai
from google.genai import types

# Packages to process the generated image:
from PIL import Image
from io import BytesIO

# Packages to load the .env file:
import os
api_key = 'AIzaSyDcnwULKPH7xqkceHW2gM9_2VMushqdO0I'
client = genai.Client(api_key=api_key)

prompt="""
POSITIVE PROMPT:
"Technical scientific diagram showing lotus leaf superhydrophobic surface structure, exploded isometric view with 5 distinct layers. Top: realistic green lotus leaf with water droplet. Second: dense vertical nanohairs, black bristles. Third: granular wax crystals, gray speckled. Fourth: dome papillae bumps, beige. Bottom: grid air layer. Clean white background, bold black text labels, clear typography, high contrast text, readable font size, precise dimensional annotations: 200nm, 100nm, 1-5μm, technical illustration style, educational diagram quality."
NEGATIVE PROMPT:
"blurry, low quality, cartoon style, hand-drawn sketch, watercolor, artistic painting, fantasy elements, unrealistic colors, cluttered background, missing labels, incorrect proportions, merged layers, unclear text, comic book style, photographic, realistic photography, shadows, lighting effects, 3D rendered, glossy surfaces, metallic textures, bright neon colors, decorative elements, ornamental details, abstract art, impressionist style, distorted perspective, incomplete diagram, missing components, overlapping text, illegible fonts, artistic interpretation, stylized illustration, painterly effects"
"""
response = client.models.generate_images(
    model="imagen-3.0-generate-002",
    prompt=prompt,
    config=types.GenerateImagesConfig(
        number_of_images=1,
    )
)

for generated_image in response.generated_images:
  image = Image.open(BytesIO(generated_image.image.image_bytes))
  display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
